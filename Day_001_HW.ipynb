# %% [markdown]
# # 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error():
    """
    請完成這個 Function 後往下執行
    """

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %% [markdown]
# 作業1：House Prices: Advanced Regression Techniques
# 1. 你選的這組資料為何重要
# 正常人一生當中購買房屋的次數不會太多
# 對於房屋的買方而言，最終價格會影響財務負擔，以及人生的許多規劃
# 若能準確預估成交價，則可以省去很多評估的時間還有避免誤判甚至買貴
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 財政部時價登錄系統，google map
# 3. 蒐集而來的資料型態為何
# 結構化的地點 價格 日期 房屋大小
# 非結構化的 街景 照片
# 4. 這組資料想解決的問題如何評估
# 分類問題: 正確率, AUC, MAP
# 回歸問題: MAE RMSE

# %% [markdown]
# 作業2：想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 1. 核心問題為何
# 如何提升 收益/司機上線時間
# 2. 資料從何而來
# 公共資料:交通部，研究論文
# 3. 蒐集而來的資料型態為何
# 結構化: 時間點，交通流量，通勤需求，通勤族群，地點
# 4. 你要回答的問題，其如何評估
# 針對分析結果，調配司機上線時間，待接客停靠地點,做出建議巡航路線

# %% [markdown]
# 作業3：
# 請點選下方檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式

# %%
# 執行 Function, 確認有沒有正常執行
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

def mean_squared_error (y, yp):
    """
    Args:
        -y:實際值
        -yp: 預測值
    Return:
        -mse: MSE
    """
    mse = MSE = sum(y - yp)**2/len(y)
    return mse


MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 167.884
# The Mean absolute error is 12.465
